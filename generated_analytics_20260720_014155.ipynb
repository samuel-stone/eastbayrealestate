# %% [markdown]
# # Real Estate Permit Analytics

# %%
|Importing Libraries|
|-------------------|

import pandas as pd
cong = "postgresql://user:password@localhost/dbname"
psycopg2.extras.real_unicode()
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 50)

# %%
|Connecting to Database|
|---------------------|

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 50)
con = "postgresql://user:password@localhost/dbname"
pd.read_sql_query("SELECT * FROM leads", con)

# %%
|Connecting to Database Prospects Features|
|-------------------------------------|
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 50)
con = "postgresql://user:password@localhost/dbname"
pd.read_sql_query("SELECT * FROM prospect_features", con)

# %%
|Plotting Histogram|
|-------------------|
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 50)
pdf = pd.read_sql_query("SELECT * FROM leads", con)
pdf['permit_date'] = pd.to_datetime(pdf['permit_date'])
pdf.plot.hist(x='permit_date', bins=20)

# %%
|Plotting Scatter Plot|
|----------------------|
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 50)
pdf = pd.read_sql_query("SELECT * FROM prospect_features", con)
pdf.plot.scatter(x='feature1', y='feature2')
